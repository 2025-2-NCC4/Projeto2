# %%
from os import replace
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio

# pio.renderers.default = "browser"

df = pd.read_csv(r"bases_tratadas\base_players.csv", sep =",")

colunas = df.columns

for coluna in colunas:
    coluna = coluna.replace("_", " ")
    print(coluna, sep="\n")
# Out:
# celular
# data nascimento
# idade
# sexo
# cidade residencial
# bairro residencial
# cidade trabalho
# bairro trabalho
# cidade escola
# bairro escola
# categoria frequentada

# %% [markdown]
# # Perfil Demográfico

# %% [markdown]
# ### Total de usuarios

# %%
total_usuarios = df["celular"].nunique()

print(f"Total de usuários: {total_usuarios}")
# Out:
# Total de usuários: 9999

# %% [markdown]
# ### Distribuição por gênero

# %%
genero = df["sexo"].value_counts().reset_index() 
genero.columns = ["Genero", "Quantidade"]

fig = px.pie( 
    genero,
    names="Genero",
    values="Quantidade",
    title="Distribuição de Players por Gênero",
    hole=0.4,
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig.show()

# %% [markdown]
# ### Faixa Etária

# %%
idade_media = df["idade"].mean()

print(f"Idada média dos Players: {idade_media}")
# Out:
# Idada média dos Players: 53.0362

# %%
fig = px.histogram(
    df,
    x="idade",
    nbins=10,
    title="Distribuição de Idade dos Players",
    color_discrete_sequence=["#636EFA"]
)

fig.update_layout(
    xaxis_title="Idade",
    yaxis_title="Número de Players",
    bargap=0.1
)

fig.show()
