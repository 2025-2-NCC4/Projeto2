# %%
import pandas as pd

df = pd.read_csv(r"base_transacoes.csv", sep=",")

# %%
colunas = df.columns

for coluna in colunas:
    print(coluna)
# Out:
# celular
# data
# hora
# nome_estabelecimento
# bairro_estabelecimento
# categoria_estabelecimento
# id_campanha
# nome_campanha
# id_cupom
# tipo_cupom
# produto
# valor_cupom
# repasse_picmoney
