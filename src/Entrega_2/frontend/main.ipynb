# %%
import pandas as pd
import numpy as np
import plotly.express as px

df = pd.read_csv(r"base_de_dados\base_lojas.csv", sep=",")

colunas = df.columns

for coluna in colunas:
    print(coluna)
# Out:
# numero_celular
# data_captura
# tipo_cupom
# tipo_loja
# local_captura
# latitude
# longitude
# nome_loja
# endereco_loja
# valor_compra
# valor_cupom

# %%
# %pip install nbformat ipython --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 24
#      21     return fig
#      23 fig = usuarios_loja(df)
# ---> 24 fig.show()
#
# File c:\Users\dudal\OneDrive\Documentos\GitHub\Projeto2\src\Entrega_2\frontend\.venv\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)   3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\dudal\OneDrive\Documentos\GitHub\Projeto2\src\Entrega_2\frontend\.venv\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
# ...
