# %%
import pandas as pd

# %%
players = pd.read_csv("Base_Cadastral_de_Players.csv", sep=";")
lojas = pd.read_csv("Base_Massa_de_Teste_com_Lojas_e_Valores.csv", sep=";")
simulacao = pd.read_csv("Base_Simulada_-_Pedestres_Av__Paulista.csv", sep=";")
transacoes = pd.read_csv("Base_de_Transacoes_e_Cupons_Capturados.csv", sep=";")

print(players.columns)
print(lojas.columns)
print(simulacao.columns)
print(transacoes.columns)
# Out:
# Index(['celular', 'data_nascimento', 'idade', 'sexo', 'cidade_residencial',
#        'bairro_residencial', 'cidade_trabalho', 'bairro_trabalho',
#        'cidade_escola', 'bairro_escola', 'categoria_frequentada'],
#       dtype='object')
# Index(['numero_celular', 'data_captura', 'tipo_cupom', 'tipo_loja',
#        'local_captura', 'latitude', 'longitude', 'nome_loja', 'endereco_loja',
#        'valor_compra', 'valor_cupom'],
#       dtype='object')
# Index(['celular', 'data', 'horario', 'local', 'latitude', 'longitude',
#        'tipo_celular', 'modelo_celular', 'possui_app_picmoney',
#        'data_ultima_compra', 'ultimo_tipo_cupom', 'ultimo_valor_capturado',
#        'ultimo_tipo_loja', 'idade', 'sexo'],
#       dtype='object')
# Index(['celular', 'data', 'hora', 'nome_estabelecimento',
#        'bairro_estabelecimento', 'categoria_estabelecimento', 'id_campanha',
#        'id_cupom', 'tipo_cupom', 'produto', 'valor_cupom', 'repasse_picmoney'],
#       dtype='object')
